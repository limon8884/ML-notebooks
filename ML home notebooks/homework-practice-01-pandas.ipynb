# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 11.09.2020
#
# Мягкий дедлайн: 04:59MSK 21.09.2020 (но лучше сдайте пораньше и успейте выспаться)
#
# Жесткий дедлайн: 23:59MSK 24.09.2020

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после жёсткого дедлайна нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате homework-practice-01-pandas-Username.ipynb, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: xx.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2

# %% [markdown]
# Ячейка с неразмеченыным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидете много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно =)

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в pandas — это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# %pylab inline  
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# c:\users\danill\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# Скачаем данные:

# %%
#!wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget 
# wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
# your code
df = pd.read_excel('end_seminar.xlsx')
df.tail(10)
# Out:
#                   timestamp                                id  rating  \
# 351 2020-05-18 23:58:33.903  8fe79f84f36e3a5d2d6745621321302c    1016
# 352 2020-05-18 23:59:20.831  f93afd8e92c336b471aa3bbbc579aefe    1298
# 353 2020-05-18 23:59:28.998  9963fc00d9405a35b894cc04a7e19855    1135
# 354 2020-05-19 08:55:39.509  98c5a2548d93f26bd4195466e93178b3    1035
# 355 2020-05-19 18:58:06.283  ba298cbd9be59b84bab33325e956f27e    1155
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# 351       NaN    NaN                 Безопасность компьютерных систем
# ...

# %% [markdown]
# #### 2. [0.5 балла] Ответьте на вопросы:
# 1. Сколько было заявок из групп 18-го года набора, а сколько из групп 17-го года?
# 2. Есть ли студенты с равными перцентилями?

# %%
# your code
print(sum(df['18_group'].notna())) # 223 заявки от 18
print(sum(df['17_group'].notna())) # 138 от 17
print(df['percentile'].unique().size) #346
print(df['id'].unique().size) #347 т.е. есть всего 2 таких студента
#df_help = df.groupby('percentile').count()
#df_help[df_help['id']== 2] # из этой таблицы видно, что это студенты с percentile = 0
# Out:
# 223
# 138
# 346
# 347

# %% [markdown]
# #### 3. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
# your code
lst = [sum(df[col].isna()) for col in df.columns] 
pd.DataFrame(df.columns).T.append(pd.DataFrame(lst).T) #number of NaNs in each column
# Out:
#            0   1       2         3      4       5       6       7         8  \
# 0  timestamp  id  rating  18_group  is_mi  fall_1  fall_2  fall_3  spring_1
# 0          0   0       0       138    343       0       0       0         0
#
#           9        10             11          12        13       14  \
# 0  spring_2  spring_3  is_first_time  percentile  17_group  blended
# 0         0         0              2           0       223      223
#
#               15
# 0  is_ml_student
# 0            304

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых.

# %%
# your code
df[['18_group', '17_group', 'is_mi', 'is_ml_student']] = df[['18_group', '17_group', 'is_mi', 'is_ml_student']].fillna(0)
df[['is_first_time', 'blended']] = df[['is_first_time', 'blended']].fillna("")

# %% [markdown]
# #### 4. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Есть ли в ней ответы "Нет"? Сколько их?
#
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию.

# %%
# your code
print(sum(df['is_first_time'] == 'Нет')) # 51 
gr = df.groupby('id')[['timestamp']].max()
df = gr.reset_index().merge(df, how='inner', right_index=False, on=['id', 'timestamp'])
#len(df)
# Out:
# 51

# %% [markdown]
# #### 5. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из курсов собрались студенты с самым высоким средним рейтингом?

# %%
# your code
print(df['blended'].unique()) #такие
print(df.groupby('blended').count()['id']) #видно, что на DevOps наибольшее кол-во студентов
print(df.groupby('blended')['rating'].mean()) #на Введение в дифференциальную геометрию с наибольшим средним
# Out:
# ['' 'Соревновательный анализ данных' 'DevOps'
#  'Введение в дифференциальную геометрию']
# blended
#                                          213
# DevOps                                    87
# Введение в дифференциальную геометрию     15
# Соревновательный анализ данных            32
# Name: id, dtype: int64
# blended
#                                           633.901408
# DevOps                                   1154.172414
# Введение в дифференциальную геометрию    1210.733333
# Соревновательный анализ данных           1144.218750
# Name: rating, dtype: float64

# %% [markdown]
# #### 6. [1 балл] Выясните, есть ли в данных студенты с абсолютно одинаковыми предпочтениями по всем курсам (не забудьте учесть blended-курсы для четверокурсников). Сколько таких наборов, которые взяли несколько студентов? Выведите их все вместе с количеством выбравших их студентов.

# %%
# your code
gr = df.groupby(['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'])['id'].count()
print(gr[gr > 1].shape[0]) # 15 таких наборов
pd.DataFrame(gr[gr > 1]).T
# Out:
# 15
# fall_1                       Statistical Learning Theory  \
# fall_2                 Анализ неструктурированных данных
# fall_3   Сбор и обработка данных с помощью краудсорсинга
# spring_1                        Обучение с подкреплением
# spring_2                          Конфликты и кооперация
# spring_3                             Компьютерное зрение
# blended                                           DevOps
# id                                                     2
#
# fall_1     Байесовские методы машинного обучения  \
# fall_2         Анализ неструктурированных данных
# fall_3      Глубинное обучение в обработке звука
# spring_1                Обучение с подкреплением
# spring_2 Генеративные модели в машинном обучении
# spring_3                     Компьютерное зрение
# blended                                   DevOps
# id                                             2
#
# fall_1                                                    \
# fall_2
# ...

# %% [markdown]
# #### 7. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
# your code
df18 = df[df['18_group'] != 0]
df17 = df[df['17_group'] != 0]
list_of_courses_18 = pd.concat([df18['fall_1'], df18['fall_2'], df18['fall_3'], df18['spring_1'], df18['spring_2'], df18['spring_3']]).unique()
list_of_courses_17 = pd.concat([df17['fall_1'], df17['fall_2'], df17['fall_3'], df17['spring_1'], df17['spring_2'], df17['spring_3']]).unique()
list(set(list_of_courses_18) & set(list_of_courses_17))
# Out:
# ['Statistical Learning Theory',
#  'Моделирование временных рядов',
#  'Численные методы',
#  'Принятие решений в условиях риска и неопределённости',
#  'Высокопроизводительные вычисления',
#  'Безопасность компьютерных систем',
#  'Сбор и обработка данных с помощью краудсорсинга']

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
# your code
print(list(set(list_of_courses_18) - set(list_of_courses_17))) # only for 18 year students
print(list(set(list_of_courses_17) - set(list_of_courses_18)))# only for 17 year students
print(df['blended'].unique()) # и blended
# Out:
# ['Дискретная оптимизация', 'Теория баз данных', 'Машинное обучение 2', 'Системы баз данных', 'Промышленное программирование на языке Java', 'Матричные вычисления', 'Компьютерные сети', 'Анализ данных в бизнесе', 'Дополнительные главы прикладной статистики', 'Язык SQL']
# ['Байесовские методы машинного обучения', 'Компьютерное зрение', 'Обучение с подкреплением', 'Глубинное обучение в обработке звука', 'Символьные вычисления', 'Методы сжатия и передачи медиаданных', 'Анализ неструктурированных данных', 'Проектирование и разработка высоконагруженных сервисов', 'Конфликты и кооперация', 'Генеративные модели в машинном обучении']
# ['' 'Соревновательный анализ данных' 'DevOps'
#  'Введение в дифференциальную геометрию']

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# #### 8. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
# your code
df['day'] = np.array([line[:10] for line in df['timestamp'].astype('str')])
gr = df.groupby('day')['rating'].mean()
f = plt.figure(figsize=(15,15))
plt.bar(gr.index, gr)
plt.title('Средний рейтинг по дням заполнения')
plt.xlabel('День заполнения')
plt.ylabel('Средний рейтинг')
plt.show()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
# your code
f.savefig('f.pdf')
df = df.drop('day', axis=1)

# %% [markdown]
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Алгоритм распределения студентов по курсам:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# Обращаем ваше внимание на следующие детали:
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно.
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * три столбца: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Формат csv: для сохранения воспользуйтесь df.to_csv('solution.csv', index=None)
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * 181, 182 - МОП; 183 - ТИ; 184 - АДИС; 185, 186 - РС; 187 - АПР; 188 - МИ
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert df.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert df.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
# ( . Y . )
df['num_of_fall_courses'] = ((df['is_mi'] != 0) | (df['17_group'] == 171) | (df['17_group'] == 172) | (df['17_group'] == 173)).astype(int) + 1
df['num_of_spring_courses'] = ((df['17_group'] == 171) | (df['17_group'] == 172) | (df['17_group'] == 173)).astype(int) + 1

# %% [markdown]
# Проверка:

# %%
col_name = 'num_of_fall_courses'    # insert your new column name as str
df_save = df
assert(df[df['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(df[df['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(df[df['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(df[df['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %%
df[df['fall_1'] == df['fall_2']] #на 0 и 2 забиваем, 1 не пройдет, а 3 придется костылить
# Out:
#                                    id               timestamp  rating  \
# 12   0d85933f07516e8871e9415c1d95ddbe 2020-05-18 14:55:38.053    1202
# 157  7fcf56aae6836855a689000a50e80360 2020-05-18 18:27:32.822    1145
# 169  86d929f6fd741e56e93cee5900298849 2020-05-15 21:34:32.550     761
# 297  e0fceae1e285f737630bb6123a1bd85d 2020-05-14 23:33:21.310    1203
#
#      18_group  is_mi                                           fall_1  \
# 12        0.0    0.0                Высокопроизводительные вычисления
# 157       0.0    0.0                 Безопасность компьютерных систем
# 169     181.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 297       0.0    0.0                Высокопроизводительные вычисления
#
#                                               fall_2  \
# 12                 Высокопроизводительные вычисления
# 157                 Безопасность компьютерных систем
# 169  Сбор и обработка данных с помощью краудсорсинга
# ...

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
# (￣^￣)ゞ
df_dop = df[df['num_of_fall_courses'] == 2]
#Костыль
df_dop = df_dop.drop(index=297)

df_dop['fall_1'] = df_dop['fall_2']
df_dop = pd.concat([df, df_dop]).reset_index() #make a 'dop' df with douuble ids for those who needs 2 courses

gr = df_dop[(df_dop['fall_1'] != 'Высокопроизводительные вычисления') &
        (df_dop['fall_1'] != 'Анализ неструктурированных данных') & 
       (df_dop['fall_1'] != 'Statistical Learning Theory')].sort_values(
    axis=0, by='percentile', ascending=True, ignore_index=False).groupby('fall_1') #drop those courses which have >30 capacity
#sort and group them
df_1_wave = pd.concat([gr.head(30)[['id', 'fall_1']], # those who passed on 2 courses and who on 1 among all students
                      df_dop[(df_dop['fall_1'] == 'Высокопроизводительные вычисления') |
        (df_dop['fall_1'] == 'Анализ неструктурированных данных') | 
       (df_dop['fall_1'] == 'Statistical Learning Theory')][['id', 'fall_1']]])

df_ = df_1_wave.groupby('id').count()
df_2 = df_[df_['fall_1'] == 2].merge(df, how='inner', left_index=True, right_on='id', suffixes=['_x', '']).drop('fall_1_x', axis=1)
df_1 = df_[df_['fall_1'] == 1].merge(df_1_wave, how='inner', left_index=True, right_on='id', suffixes=['_x', '']).drop('fall_1_x', axis=1)
df_1 = df_1.merge(df, how='inner', on='id', suffixes=['_x', ''])

df_1['fall_course1'] = df_1['fall_1_x']
df_1 = df_1.drop('fall_1_x', axis=1)

df_2['fall_course1'] = df_2['fall_1']
df_2['fall_course2'] = df_2['fall_2']

df = pd.concat([df_1, df_2])[['id', 'fall_course1', 'fall_course2']].merge(df, on='id', how='outer')

# все тот же костыль, чтоб чел умел заполнять анкеты
df['fall_2'][175] = 'Безопасность компьютерных систем'
df['fall_3'][175] = 'Безопасность компьютерных систем'
#pd.options.display.max_rows = 15
# Out:
# <ipython-input-602-b3e937685c75>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fall_2'][175] = 'Безопасность компьютерных систем'
# <ipython-input-602-b3e937685c75>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fall_3'][175] = 'Безопасность компьютерных систем'

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
#!wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
fir_col_name = 'is_first_place'      # insert name of your new column with is_first_place as str
last_col_name = 'is_last_place'     # insert name of your new column with is_last_place as str

df_dop = df[df['fall_course2'].notna()]
df_dop['fall_course1'] = df_dop['fall_course2']
df_dop = pd.concat([df, df_dop]).reset_index()
df_best = df_dop.sort_values(axis=0, by='percentile', ascending=True, ignore_index=False).groupby('fall_course1').head(1).drop(269)
#drop the first one in NaN
df_best['is_first_place'] = True
df = df.merge(df_best.drop_duplicates(['id'])[['id', 'is_first_place']], on='id', how='left')

df_dop = df[df['fall_course2'].notna()]
df_dop['fall_course1'] = df_dop['fall_course2']
df_dop = pd.concat([df, df_dop]).reset_index()
df_best = df_dop.sort_values(axis=0, by='percentile', ascending=False, ignore_index=False).groupby('fall_course1').head(1).drop(329)
df_best['is_last_place'] = True
df = df.merge(df_best.drop_duplicates(['id'])[['id', 'is_last_place']], on='id', how='left')


assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       == 
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()
# Out:
# <ipython-input-604-8fc7a382aad0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dop['fall_course1'] = df_dop['fall_course2']
# <ipython-input-604-8fc7a382aad0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dop['fall_course1'] = df_dop['fall_course2']

# %% [markdown]
# #### 3. [3 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
# сделаем dataframe, в котором будет отслеживать количество свободных мест
df_1 = df[['id', 'fall_course1']]
df_1['get_fall_course'] = df_1['fall_course1']
df_2 = df[['id', 'fall_course2']]
df_2['get_fall_course'] = df_2['fall_course2']

df_available = pd.concat([df_1, df_2]).drop(['fall_course1', 'fall_course2'], axis=1).dropna().groupby('get_fall_course').count()
df_available['default'] = 30
df_available['default']['Statistical Learning Theory'] = 60
df_available['default']['Анализ неструктурированных данных'] = 1000 
df_available['default']['Высокопроизводительные вычисления'] = 60
df_available['after_1_wave'] = df_available['default'] - df_available['id']
df_available = df_available.sort_index()[['after_1_wave']]
df_available
# Out:
# <ipython-input-605-cc342e7a8442>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['get_fall_course'] = df_1['fall_course1']
# <ipython-input-605-cc342e7a8442>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['get_fall_course'] = df_2['fall_course2']
#                                                     after_1_wave
# get_fall_course
# Statistical Learning Theory                                   27
# Анализ неструктурированных данных                            952
# ...

# %%
# 2 ВОЛНА
# найдем лузеров, которые не набрали нужное кол-во курсов в 1 волну
df_2_wave_2 = df[((df['num_of_fall_courses'] == 2) & df['fall_course2'].isna())]
df_2_wave_1 = df[((df['num_of_fall_courses'] == 1) & df['fall_course1'].isna())] 

df_2_wave_2['2prior'] = df_2_wave_2['fall_3']
df_2_wave_1['2prior'] = df_2_wave_1['fall_2']
df_2_wave = pd.concat([df_2_wave_2, df_2_wave_1]) # Так вот же они!

gr = df_2_wave.sort_values(axis=0, by='percentile', ascending=True).groupby('2prior')
df_passed_2_wave = pd.concat([gr.get_group(course)[:df_available['after_1_wave'][course]] for course in gr.groups.keys()]) 
# это те, кто прошли во 2 волне на 1 курс

df_1 = df_passed_2_wave[df_passed_2_wave['fall_course1'].isna()]
df_1['fall_course1'] = df_1['2prior']
df_2 = df_passed_2_wave[df_passed_2_wave['fall_course1'].notna()]
df_2['fall_course2'] = df_2['2prior']
df_2_wave.sort_values(axis=0, by='percentile', ascending=False)
df = pd.concat([df.drop(df_passed_2_wave.index), df_1, df_2])
# Out:
# <ipython-input-606-f4580e531133>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2_wave_2['2prior'] = df_2_wave_2['fall_3']
# <ipython-input-606-f4580e531133>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2_wave_1['2prior'] = df_2_wave_1['fall_2']
# <ipython-input-606-f4580e531133>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# 3 ВОЛНА

# сделаем dataframe, в котором будет отслеживать количество свободных мест
df_1 = df[['id', 'fall_course1']]
df_1['get_fall_course'] = df_1['fall_course1']
df_2 = df[['id', 'fall_course2']]
df_2['get_fall_course'] = df_2['fall_course2']

df_available = pd.concat([df_1, df_2]).drop(['fall_course1', 'fall_course2'], axis=1).dropna().groupby('get_fall_course').count()
df_available['default'] = 30
df_available['default']['Statistical Learning Theory'] = 60
df_available['default']['Анализ неструктурированных данных'] = 1000 
df_available['default']['Высокопроизводительные вычисления'] = 60
df_available['after_2_wave'] = df_available['default'] - df_available['id']
df_available = df_available.sort_index()[['after_2_wave']]
df_available
# Out:
# <ipython-input-607-1181ec243f4a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['get_fall_course'] = df_1['fall_course1']
# <ipython-input-607-1181ec243f4a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['get_fall_course'] = df_2['fall_course2']
#                                                     after_2_wave
# get_fall_course
# Statistical Learning Theory                                   19
# Анализ неструктурированных данных                            947
# ...

# %%
# 3 ВОЛНА
# найдем лузеров, которые не набрали нужное кол-во курсов во 2 волну. Среди 18 года. 17 поможет уже только учебка
df_3_wave = df[(df['num_of_fall_courses'] == 1) & df['fall_course1'].isna()] # Так вот же они!
df_3_wave['3prior'] = df_3_wave['fall_3']

gr = df_3_wave.sort_values(axis=0, by='percentile', ascending=True).groupby('3prior')
df_passed_3_wave = pd.concat([gr.get_group(course)[:df_available['after_2_wave'][course]] for course in gr.groups.keys()]) 
# это те, кто прошли в 3 волне

df_passed_3_wave['fall_course1'] = df_passed_3_wave['3prior']
df = pd.concat([df.drop(df_passed_3_wave.index), df_passed_3_wave])
# Out:
# <ipython-input-608-227505856468>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3_wave['3prior'] = df_3_wave['fall_3']

# %%
pd.options.display.max_rows = 999
df['fall_course1'].fillna('???', inplace=True)
df_1 = df[df['num_of_fall_courses'] == 1]
df_1['fall_course2'].fillna('-', inplace=True)
df_2 = df[df['num_of_fall_courses'] == 2]
df_2['fall_course2'].fillna('???', inplace=True)
df = pd.concat([df_1, df_2])
# Out:
# c:\users\danill\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# c:\users\danill\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
# Мой никнейм: limon, ссылочку на посылку не умею, я тупой))0
#мб это она https://contest.yandex.ru/contest/19782/problems/?success=34745859#528867/2020_09_14/oF91l8YOQm

df_res = pd.DataFrame()
df_res['ID'] = df['id']
df_res['course1'] = df['fall_course1']
df_res['course2'] = df['fall_course2']
df_res.to_csv('res_fall.csv', index=None)

# %%
#df = df_save

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (https://contest.yandex.ru/contest/19782/problems/A/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# *Дисклеймер:*
#
# Контест выдаётся для самопроверки. Если ваша посылка получила ОК, то код, скорее всего, правильный. Но при этом оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# **Дополнительное задание. [2 бонусных балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.**
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
# (￣^'￣)ゞ
df = df[['id', '18_group', 'spring_1', 'spring_2', 'spring_3', 'percentile', '17_group', 'is_ml_student', 'num_of_spring_courses']].reset_index()

# %%
# сделаем dataframe, в котором будет отслеживать количество свободных мест
df_available = pd.DataFrame(index=pd.concat([df['spring_1'], df['spring_3'], df['spring_3']]).unique())
df_available['default'] = 30
df_available['default']['Обучение с подкреплением'] = 60
df_available['default']['Анализ данных в бизнесе'] = 60
df_available
# Out:
#                                                     default
# Дискретная оптимизация                                   30
# Компьютерные сети                                        30
# Промышленное программирование на языке Java              30
# Методы сжатия и передачи медиаданных                     30
# Конфликты и кооперация                                   30
# Анализ данных в бизнесе                                  60
# Машинное обучение 2                                      30
# Проектирование и разработка высоконагруженных с...       30
# Дополнительные главы прикладной статистики               30
# Обучение с подкреплением                                 60
# Численные методы                                         30
# Системы баз данных                                       30
# Компьютерное зрение                                      30
# Символьные вычисления                                    30
# Генеративные модели в машинном обучении                  30

# %%
# боремся с умными МОПами
df[((df['spring_1'] == 'Машинное обучение 2') | (df['spring_2'] == 'Машинное обучение 2') | (df['spring_3'] == 'Машинное обучение 2')) & (df['is_ml_student'] == 1)]
# Out:
#      index                                id  18_group  \
# 68      73  6ed89e424179b0510e3f7c0cb7369ad6     187.0
# 110    120  abceddfa2fc4eae8cff4a4e712abb3fb     183.0
# 177    200  fc2c60b8004aa91bc272df84628621ff     183.0
# 207    293  5daee1bd98559bb2c52373e416942225     182.0
# 251    342  f0f6f3881894172a0f04e79b554b49e6     181.0
#
#                     spring_1                                     spring_2  \
# 68   Анализ данных в бизнесе  Промышленное программирование на языке Java
# 110      Машинное обучение 2  Промышленное программирование на языке Java
# 177       Системы баз данных                          Машинное обучение 2
# 207      Машинное обучение 2  Промышленное программирование на языке Java
# 251      Машинное обучение 2                             Численные методы
#
#                                        spring_3  percentile  17_group  \
# 68                          Машинное обучение 2    0.838565       0.0
# ...

# %%
ind = [110, 207, 251]
df['spring_1'].loc[ind] = df['spring_2'].loc[ind]
df['spring_2'].loc[ind] = df['spring_3'].loc[ind]
df['spring_3'].loc[ind] = 'Дискретная оптимизация' 
df['spring_3'].loc[68] = 'Дискретная оптимизация' 
df['spring_2'].loc[177] = df['spring_3'].loc[177]
df['spring_3'].loc[177] = 'Дискретная оптимизация'
# Out:
# c:\users\danill\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df[df['spring_1'] == df['spring_2']] #на 0 1 2 забиваем (у них по одному курсу), а 3 b 4 придется костылить (оба проходят в первой волне)
# Out:
#      index                                id  18_group  \
# 91      99  86d929f6fd741e56e93cee5900298849     181.0
# 133    147  c7f347b466ff14ec85103f61c4d6ff8e     187.0
# 134    148  c7f617262a8d9350bcbba27f6d65d86a     181.0
# 264    175  e0fceae1e285f737630bb6123a1bd85d       0.0
# 330    306  7fcf56aae6836855a689000a50e80360       0.0
#
#                                               spring_1  \
# 91          Дополнительные главы прикладной статистики
# 133                                Машинное обучение 2
# 134                                Машинное обучение 2
# 264  Проектирование и разработка высоконагруженных ...
# 330                              Символьные вычисления
#
#                                               spring_2  \
# 91          Дополнительные главы прикладной статистики
# 133                                Машинное обучение 2
# 134                                Машинное обучение 2
# 264  Проектирование и разработка высоконагруженных ...
# ...

# %%
df['spring_2'].loc[264] = 'Символьные вычисления'
df['spring_3'].loc[264] = 'Дискретная оптимизация' #чтоб не прошел
df = df.drop(330).drop('index', axis=1) # 7fcf56aae6836855a689000a50e80360 этого умника просто уберем
# Out:
# c:\users\danill\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
# 1 волна

df_dop = df[df['num_of_spring_courses'] == 2]

df_dop['1prior'] = df_dop['spring_2']
df['1prior'] = df['spring_1']
df_1_wave = pd.concat([df, df_dop])#.reset_index() #make a 'dop' df with douuble ids for those who needs 2 courses

gr = df_1_wave.sort_values(axis=0, by='percentile', ascending=True).groupby('1prior')
df_passed_1_wave = pd.concat([gr.get_group(course)[:df_available['default'][course]] for course in gr.groups.keys()]) 

df_ = df_passed_1_wave.groupby('id').count()[['1prior']]
df_2 = df_[df_['1prior'] == 2].merge(df, left_index=True, right_on='id', suffixes=['_x', '']).drop('1prior_x', axis=1)
df_2['course1'] = df_2['spring_1']
df_2['course2'] = df_2['spring_2']

df_1 = df_[df_['1prior'] == 1].merge(df_passed_1_wave, left_index=True, right_on='id',
                                     suffixes=['_x', '']).drop('1prior_x', axis=1)
df_1['course1'] = df_1['1prior']

df = pd.concat([df_1, df_2])[['id', 'course1', 'course2']].merge(df, how='outer', on='id')

df_1 = df[['id', 'course1']]
df_1['get_course'] = df_1['course1']
df_2 = df[['id', 'course2']]
df_2['get_course'] = df_2['course2']
df_available = pd.concat([df_1, df_2]).drop(['course1', 'course2'], axis=1).dropna().groupby('get_course').count()
df_available['default'] = 30
df_available['default']['Анализ данных в бизнесе'] = 60
df_available['default']['Обучение с подкреплением'] = 60
df_available['after_1_wave'] = df_available['default'] - df_available['id']
df_available = df_available.sort_index()[['after_1_wave']]
df_available
# Out:
# <ipython-input-687-734542638712>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dop['1prior'] = df_dop['spring_2']
# <ipython-input-687-734542638712>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['get_course'] = df_1['course1']
# <ipython-input-687-734542638712>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# 2 ВОЛНА
# найдем лузеров, которые не набрали нужное кол-во курсов в 1 волну
df_2_wave_2 = df[((df['num_of_spring_courses'] == 2) & df['course2'].isna())]
df_2_wave_1 = df[((df['num_of_spring_courses'] == 1) & df['course1'].isna())] 

df_2_wave_2['2prior'] = df_2_wave_2['spring_3']
df_2_wave_1['2prior'] = df_2_wave_1['spring_2']
df_2_wave = pd.concat([df_2_wave_2, df_2_wave_1]) # Так вот же они!

gr = df_2_wave.sort_values(axis=0, by='percentile', ascending=True).groupby('2prior')
df_passed_2_wave = pd.concat([gr.get_group(course)[:df_available['after_1_wave'][course]] for course in gr.groups.keys()]) 
# это те, кто прошли во 2 волне на 1 курс

df_1 = df_passed_2_wave[df_passed_2_wave['course1'].isna()]
df_1['course1'] = df_1['2prior']
df_2 = df_passed_2_wave[df_passed_2_wave['course1'].notna()]
df_2['course2'] = df_2['2prior']
df_2_wave.sort_values(axis=0, by='percentile', ascending=False)
df = pd.concat([df.drop(df_passed_2_wave.index), df_1, df_2])
# Out:
# <ipython-input-688-b5f015337802>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2_wave_2['2prior'] = df_2_wave_2['spring_3']
# <ipython-input-688-b5f015337802>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2_wave_1['2prior'] = df_2_wave_1['spring_2']
# <ipython-input-688-b5f015337802>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_1 = df[['id', 'course1']]
df_1['get_course'] = df_1['course1']
df_2 = df[['id', 'course2']]
df_2['get_course'] = df_2['course2']
df_available = pd.concat([df_1, df_2]).drop(['course1', 'course2'], axis=1).dropna().groupby('get_course').count()
df_available['default'] = 30
df_available['default']['Анализ данных в бизнесе'] = 60
df_available['default']['Обучение с подкреплением'] = 60
df_available['after_2_wave'] = df_available['default'] - df_available['id']
df_available = df_available.sort_index()[['after_2_wave']]
df_available
# Out:
# <ipython-input-689-46a070f0ca00>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['get_course'] = df_1['course1']
# <ipython-input-689-46a070f0ca00>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['get_course'] = df_2['course2']
#                                                     after_2_wave
# get_course
# Анализ данных в бизнесе                                       32
# Генеративные модели в машинном обучении                       12
# ...

# %%
# 3 ВОЛНА
# найдем лузеров, которые не набрали нужное кол-во курсов во 2 волну. Среди 18 года. 17 поможет уже только учебка
df_3_wave = df[(df['num_of_spring_courses'] == 1) & df['course1'].isna()] # Так вот же они!
df_3_wave['3prior'] = df_3_wave['spring_3']

gr = df_3_wave.sort_values(axis=0, by='percentile', ascending=True).groupby('3prior')
df_passed_3_wave = pd.concat([gr.get_group(course)[:df_available['after_2_wave'][course]] for course in gr.groups.keys()]) 
# это те, кто прошли в 3 волне

df_passed_3_wave['course1'] = df_passed_3_wave['3prior']
df = pd.concat([df.drop(df_passed_3_wave.index), df_passed_3_wave])
# Out:
# <ipython-input-690-28c38cfae524>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3_wave['3prior'] = df_3_wave['spring_3']

# %%
pd.options.display.max_rows = 999
df['course1'].fillna('???', inplace=True)
df_1 = df[df['num_of_spring_courses'] == 1]
df_1['course2'].fillna('-', inplace=True)
df_2 = df[df['num_of_spring_courses'] == 2]
df_2['course2'].fillna('???', inplace=True)
df = pd.concat([df_1, df_2])
# Out:
# c:\users\danill\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# c:\users\danill\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
# Мой никнейм: limon, ссылочку на посылку не умею, я тупой))0
#мб это она https://contest.yandex.ru/contest/19782/problems/B/?success=34747572#528867/2020_09_14/7D5nIGtcFE

df_res = pd.DataFrame()
df_res['ID'] = df['id']
df_res['course1'] = df['course1']
df_res['course2'] = df['course2']
df_help = pd.DataFrame(['7fcf56aae6836855a689000a50e80360', 'Символьные вычисления', '???']).T
df_help.columns = ['ID', 'course1', 'course2']
df_res = df_res.append(df_help).reset_index().drop('index', axis=1)
df_res
df_res.to_csv('res_spring.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (https://contest.yandex.ru/contest/19782/problems/B/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:

# %%
# Оценка 12 (и 2 дня штрафа)
